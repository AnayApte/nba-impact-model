# %%
from nba_api.stats.endpoints import leaguegamelog

# %%
import pandas as pd

# %%
import time

# %%
gamelog = leaguegamelog.LeagueGameLog(season='2025-26')

# %%
df = gamelog.get_data_frames()[0]

# %%
print (df.shape)
# Out:
# (2460, 29)

# %%
print (df.columns.tolist())
# Out:
# ['SEASON_ID', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_NAME', 'GAME_ID', 'GAME_DATE', 'MATCHUP', 'WL', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'PLUS_MINUS', 'VIDEO_AVAILABLE']

# %%
df.head()
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME     GAME_ID  \
# 0     22025  1610612745               HOU        Houston Rockets  0022500001
# 1     22025  1610612747               LAL     Los Angeles Lakers  0022500002
# 2     22025  1610612760               OKC  Oklahoma City Thunder  0022500001
# 3     22025  1610612744               GSW  Golden State Warriors  0022500002
# 4     22025  1610612766               CHA      Charlotte Hornets  0022500080
#
#     GAME_DATE      MATCHUP WL  MIN  FGM  ...  DREB  REB  AST  STL  BLK  TOV  \
# 0  2025-10-21    HOU @ OKC  L  290   43  ...    36   52   23    6    5   25
# 1  2025-10-21  LAL vs. GSW  L  240   42  ...    32   39   23    7    2   20
# 2  2025-10-21  OKC vs. HOU  W  290   46  ...    27   38   29   12    4   12
# 3  2025-10-21    GSW @ LAL  W  240   38  ...    31   40   29   10    4   19
# 4  2025-10-22  CHA vs. BKN  W  240   48  ...    36   50   33    5    5   17
#
#    PF  PTS  PLUS_MINUS  VIDEO_AVAILABLE
# 0  26  124          -1                1
# 1  21  109         -10                1
# 2  27  125           1                1
# 3  27  119          10                1
# 4  25  136          19                1
#
# [5 rows x 29 columns]

# %%
from nba_api.stats.endpoints import playbyplayv3

# %%
print(df['GAME_ID'].head(10))
# Out:
# 0    0022500001
# 1    0022500002
# 2    0022500001
# 3    0022500002
# 4    0022500080
# 5    0022500081
# 6    0022500088
# 7    0022500004
# 8    0022500082
# 9    0022500085
# Name: GAME_ID, dtype: object

# %%
time.sleep(1)

# %%
pbp = playbyplayv3.PlayByPlayV3(game_id='0022500001')

# %%
pbp_df = pbp.get_data_frames()[0]

# %%
print(pbp_df.shape)
# Out:
# (611, 24)

# %%
print(pbp_df.columns.tolist())
# Out:
# ['gameId', 'actionNumber', 'clock', 'period', 'teamId', 'teamTricode', 'personId', 'playerName', 'playerNameI', 'xLegacy', 'yLegacy', 'shotDistance', 'shotResult', 'isFieldGoal', 'scoreHome', 'scoreAway', 'pointsTotal', 'location', 'description', 'actionType', 'subType', 'videoAvailable', 'shotValue', 'actionId']

# %%
pbp_df.head(20)
# Out:
#         gameId  actionNumber        clock  period      teamId teamTricode  \
# 0   0022500001             2  PT12M00.00S       1           0
# 1   0022500001             4  PT12M00.00S       1  1610612760         OKC
# 2   0022500001             8  PT11M36.00S       1  1610612745         HOU
# 3   0022500001             9  PT11M31.00S       1  1610612760         OKC
# 4   0022500001            10  PT11M26.00S       1  1610612760         OKC
# 5   0022500001            12  PT11M26.00S       1  1610612745         HOU
# 6   0022500001            14  PT11M26.00S       1  1610612760         OKC
# 7   0022500001            15  PT11M08.00S       1  1610612745         HOU
# 8   0022500001            16  PT11M04.00S       1  1610612745         HOU
# 9   0022500001            17  PT11M02.00S       1  1610612745         HOU
# 10  0022500001            18  PT10M50.00S       1  1610612760         OKC
# 11  0022500001            20  PT10M40.00S       1  1610612760         OKC
# 12  0022500001            21  PT10M24.00S       1  1610612745         HOU
# 13  0022500001            23  PT10M24.00S       1           0
# 14  0022500001            24  PT10M24.00S       1           0
# 15  0022500001            25  PT10M11.00S       1  1610612760         OKC
# 16  0022500001            25  PT10M11.00S       1  1610612745         HOU
# 17  0022500001            27  PT10M07.00S       1  1610612745         HOU
# 18  0022500001            29  PT09M52.00S       1  1610612760         OKC
# 19  0022500001            30  PT09M35.00S       1  1610612745         HOU
#
#       personId          playerName            playerNameI  xLegacy  ...  \
# 0            0                                                   0  ...
# 1      1631096            Holmgren            C. Holmgren        0  ...
# 2      1630578              Sengun              A. Sengun     -179  ...
# 3      1641717             Wallace             C. Wallace        0  ...
# 4      1631096            Holmgren            C. Holmgren        0  ...
# 5      1631095           Smith Jr.           J. Smith Jr.        0  ...
# 6      1631096            Holmgren            C. Holmgren        0  ...
# 7      1641708            Thompson            A. Thompson      233  ...
# 8      1631095           Smith Jr.           J. Smith Jr.        0  ...
# 9      1631095           Smith Jr.           J. Smith Jr.       -7  ...
# 10     1631096            Holmgren            C. Holmgren       64  ...
# 11     1631096            Holmgren            C. Holmgren        0  ...
# 12     1630578              Sengun              A. Sengun       72  ...
# 13  1610612745                                                   0  ...
# 14  1610612745                                                   0  ...
# 15     1628983  Gilgeous-Alexander  S. Gilgeous-Alexander        0  ...
# 16     1630578              Sengun              A. Sengun        0  ...
# 17      201142              Durant              K. Durant        0  ...
# 18     1631096            Holmgren            C. Holmgren       59  ...
# 19     1631095           Smith Jr.           J. Smith Jr.      164  ...
#
#     scoreHome  scoreAway pointsTotal  location  \
# 0           0          0           0
# 1                                  0         h
# 2                                  0         v
# 3                                  0         h
# 4           2          0           2         h
# 5                                  0         v
# 6           3          0           3         h
# 7                                  0         v
# 8                                  0         v
# 9           3          2           5         v
# 10          5          2           7         h
# 11                                 0         h
# 12                                 0         v
# 13                                 0         v
# 14                                 0         v
# 15                                 0         h
# 16                                 0         v
# 17          5          4           9         v
# 18          7          4          11         h
# 19          7          7          14         v
#
#                                           description   actionType  \
# 0                   Start of 1st Period (7:44 PM EST)       period
# 1       Jump Ball Holmgren vs. Adams: Tip to Thompson    Jump Ball
# 2                       MISS Sengun 25' 3PT Jump Shot  Missed Shot
# 3                       Wallace REBOUND (Off:0 Def:1)      Rebound
# 4   Holmgren 1' Cutting Layup Shot (2 PTS) (Dort 1...    Made Shot
# 5                  Smith Jr. S.FOUL (P1.T1) (E.Dalen)         Foul
# 6                  Holmgren Free Throw 1 of 1 (3 PTS)   Free Throw
# 7                         MISS Thompson 3PT Jump Shot  Missed Shot
# 8                     Smith Jr. REBOUND (Off:1 Def:0)      Rebound
# 9                  Smith Jr. 1' Putback Layup (2 PTS)    Made Shot
# 10  Holmgren 7' Floating Jump Shot (5 PTS) (Wallac...    Made Shot
# 11           Holmgren Violation:Kicked Ball (Z.Zarba)    Violation
# 12                   MISS Sengun 15' Pullup Jump Shot  Missed Shot
# 13                                    Rockets Rebound      Rebound
# 14                 Rockets Turnover: Shot Clock (T#1)     Turnover
# 15       Gilgeous-Alexander Bad Pass Turnover (P1.T1)     Turnover
# 16                               Sengun STEAL (1 STL)
# 17       Durant Running Dunk (2 PTS) (Thompson 1 AST)    Made Shot
# 18           Holmgren 13' Turnaround Fadeaway (7 PTS)    Made Shot
# 19  Smith Jr. 26' 3PT Jump Shot (5 PTS) (Thompson ...    Made Shot
#
#                      subType videoAvailable shotValue actionId
# 0                      start              1         0        1
# 1                                         1         0        2
# 2                  Jump Shot              1         3        3
# 3                    Unknown              1         0        4
# 4         Cutting Layup Shot              1         2        5
# 5                   Shooting              1         0        6
# 6          Free Throw 1 of 1              1         0        7
# 7                  Jump Shot              1         3        8
# 8                    Unknown              1         0        9
# 9         Putback Layup Shot              1         2       10
# 10        Floating Jump shot              1         2       11
# 11               Kicked Ball              0         0       12
# 12          Pullup Jump shot              1         2       13
# 13                   Unknown              0         0       14
# 14       Shot Clock Turnover              1         0       15
# 15                  Bad Pass              1         0       16
# 16                                        1         0       17
# 17         Running Dunk Shot              1         2       18
# 18  Turnaround Fadeaway shot              1         2       19
# 19                 Jump Shot              1         3       20
#
# [20 rows x 24 columns]
